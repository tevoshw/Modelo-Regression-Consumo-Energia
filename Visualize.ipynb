# %%
from Data import df_energia, X_tensor, Y_tensor
import matplotlib.pyplot as plt
import seaborn as sns

# %%
independent_vars = ['Temperatura Média (°C)', 'Horas de Luz Solar', 'Número de Aparelhos', 'Área Residencial (m²)']

for var in independent_vars:
    sns.scatterplot(x=df_energia[var], y=df_energia['Consumo de Energia (kWh)'])
    plt.title(f"{var} vs Consumo de Energia")
    plt.show()
